# %%
import sys
sys.path.append('..')

from src.autoresevaluator.main import AutoResEvaluator

# %%
params = {
    'learning_rate': {'type': 'log_float', 'args': [1e-8, 0.1]},
    'iterations': {'type': 'log_float', 'args': [100, 1000]},
    "lambda": 1
}

# %%
are = AutoResEvaluator(
    dataset_name='titanic',
    model_path='/Users/tanakatouma/vscode/autores-evaluator/test/logistic_regression.py',
    params=params,
    valuation_index='roc_auc',
    datasave_path=None
    )

# %%
are.exec()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:4: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:4: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# /Users/tanakatouma/vscode/autores-evaluator/test/copy_file.py:9: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
